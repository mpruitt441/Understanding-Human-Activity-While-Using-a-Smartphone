# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(300)*4

y = np.sin(x)+np.random.rand(len(x))/3

reg = RandomForestRegressor()
reg.fit(X,y)
g = reg.predict(X)

plt.scatter(x,y,alpha=0.3)
plt.scatter(x,g,alpha=0.3)
plt.show()
# Out:
# /ext/anaconda5/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
len(x),len(g)
# Out:
# (300, 75)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
X = x.reshape((len(x),1))
y = y

X_train,X_test,y_train,y_test = train_test_split(X,y)

reg = MLPRegressor([5,5,5],activation="relu",max_iter=1000)
reg.fit(X_train,y_train)
g = reg.predict(X)
reg.score(X_test,y_test)
# Out:
# 0.8827477065873388

# %%
x = np.random.rand(300*300).reshape((300,300))*4
f = np.sin(x[:,0])+np.random.rand(x.shape[0])/3
y = np.sign((x[:,1]<f)*2-1)
plt.scatter(x[:,0][y==+1],x[:,1][y==+1])
plt.scatter(x[:,0][y==-1],x[:,1][y==-1])

# %%
X = np.c_[x[:,0],x[:,1]]
y = y
X.shape
# Out:
# (300, 2)

# %%
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
clf = svm.SVC(gamma=10,C=1)
#clf = KNeighborsClassifier(p=1)
X_train,X_test,y_train,y_test = train_test_split(X,y)
#clf.fit(X_train,y_train)
#clf.score(X_test,y_test)

# %%
from sklearn.model_selection import cross_validate
for gamma in [1,10,100]:
    for C in [1,10,100]:
        clf = svm.SVC(gamma=gamma,C=C)
        result = cross_validate(clf,X_train,y_train)['test_score'].mean()
        print("with gamma=",gamma,"and C = ",C,"score = ",result)
# Out:
# with gamma= 1 and C =  1 score =  0.9688841473051998
# with gamma= 1 and C =  10 score =  0.9778931563142089
# with gamma= 1 and C =  100 score =  0.9554891733839103
# with gamma= 10 and C =  1 score =  0.9598767188240873
# with gamma= 10 and C =  10 score =  0.9554306938517465
# with gamma= 10 and C =  100 score =  0.9554306938517465
# with gamma= 100 and C =  1 score =  0.8534344871186977
# with gamma= 100 and C =  10 score =  0.8578204520309783
# with gamma= 100 and C =  100 score =  0.8578204520309783
# /ext/anaconda5/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# ...

# %%
clf = svm.SVC(gamma=1,C=10)
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
clf.fit(X,y
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
clf.predict([[0.2,0.3],[.8,10]])
# Out:
# array([ 1, -1])
